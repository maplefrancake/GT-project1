# %%
python -m pip show scikit-learn
# Out:
#   File "/var/folders/bb/t503m8015rq6zv0nth3mlmj80000gn/T/ipykernel_3949/3294572110.py", line 1
#     python -m pip show scikit-learn
#                 ^
# SyntaxError: invalid syntax
