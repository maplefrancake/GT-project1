# %%
# Dependencies
import requests
import json
import pandas as pd
from config import eia_api_key_hugh

# %% [markdown]
# This API request is to the EIA and is for electricity consumed based on retail sales data from utilities via EIA's State Energy Data System (SEDS)
#
# API route: State Energy Data System (SEDS)
# Frequency: Annual  2021 only
# Data type: nothing specified, only "value (required)"
# Facet, filtered by Unique Series Identifier (SERIESID):  ESTCP (Electricity, total consumption (i.e. retail sales) (note: ESTCP reports the data in kWh. A similar facet  (facetid: ESTCB) reports the data in Btu.
# https://www.eia.gov/opendata/browser/seds

# %%
#Designate base url
base_url = "https://api.eia.gov/v2/seds/data/"

# %%
#Note the parameter syntax, including placement of quotes, colons and commas
#The final comma, in the length row, is intentional in order to accomodate
#additional parameters in the future.
#The first parameter is my personal API key for EIA's API.

parameters = {
    "api_key": eia_api_key_hugh,
    "frequency": "annual",
    "data[0]": "value",
    "facets[seriesId][]": ["ESTCP"],
    "start": "2021",
    "end": "2021",
    "offset": "0",
    "length": "5000",
}

# %%
# Performing a GET Request and saving the 
# API's response within a variable.
#params is one of the parameters in the response.get method and refers
#to the API parameters, although params is itself a parameter for the response.get method.

response = requests.get(base_url, params = parameters)
response_json = response.json()
print(response.json())
# Out:
# {'response': {'total': 52, 'dateFormat': 'YYYY', 'frequency': 'annual', 'data': [{'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'TN', 'stateDescription': 'Tennessee', 'value': 99621, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'DE', 'stateDescription': 'Delaware', 'value': 11480, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'GA', 'stateDescription': 'Georgia', 'value': 137364, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'IN', 'stateDescription': 'Indiana', 'value': 99740, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'AR', 'stateDescription': 'Arkansas', 'value': 48663, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'MS', 'stateDescription': 'Mississippi', 'value': 48015, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'ID', 'stateDescription': 'Idaho', 'value': 25286, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'WI', 'stateDescription': 'Wisconsin', 'value': 69427, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'OH', 'stateDescription': 'Ohio', 'value': 147718, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'KY', 'stateDescription': 'Kentucky', 'value': 74517, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'SD', 'stateDescription': 'South Dakota', 'value': 13041, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'OR', 'stateDescription': 'Oregon', 'value': 54135, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'NH', 'stateDescription': 'New Hampshire', 'value': 10867, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'VA', 'stateDescription': 'Virginia', 'value': 125245, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'RI', 'stateDescription': 'Rhode Island', 'value': 7398, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'MN', 'stateDescription': 'Minnesota', 'value': 66589, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'NJ', 'stateDescription': 'New Jersey', 'value': 73070, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumption (i.e., retail sales)', 'stateId': 'PA', 'stateDescription': 'Pennsylvania', 'value': 143340, 'unit': 'Million kilowatthours'}, {'period': 2021, 'seriesId': 'ESTCP', 'seriesDescription': 'Electricity total consumpt ...

# %%
#I am 'pretty printing' the result with the indent and sort_keys options
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "apiVersion": "2.1.2",
#     "request": {
#         "command": "/v2/seds/data/",
#         "params": {
#             "api_key": "39ZLs9eshRJNS0r0m2m35YXX2cFn36DzdZVgyzvh",
#             "data": [
#                 "value"
#             ],
#             "end": 2021,
#             "facets": {
#                 "seriesId": [
#                     "ESTCP"
#                 ]
#             },
#             "frequency": "annual",
#             "length": 5000,
#             "offset": 0,
#             "start": 2021
#         }
#     },
#     "response": {
#         "data": [
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Tennessee",
#                 "stateId": "TN",
#                 "unit": "Million kilowatthours",
#                 "value": 99621
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Delaware",
#                 "stateId": "DE",
#                 "unit": "Million kilowatthours",
#                 "value": 11480
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Georgia",
#                 "stateId": "GA",
#                 "unit": "Million kilowatthours",
#                 "value": 137364
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Indiana",
#                 "stateId": "IN",
#                 "unit": "Million kilowatthours",
#                 "value": 99740
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Arkansas",
#                 "stateId": "AR",
#                 "unit": "Million kilowatthours",
#                 "value": 48663
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Mississippi",
#                 "stateId": "MS",
#                 "unit": "Million kilowatthours",
#                 "value": 48015
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Idaho",
#                 "stateId": "ID",
#                 "unit": "Million kilowatthours",
#                 "value": 25286
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Wisconsin",
#                 "stateId": "WI",
#                 "unit": "Million kilowatthours",
#                 "value": 69427
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Ohio",
#                 "stateId": "OH",
#                 "unit": "Million kilowatthours",
#                 "value": 147718
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Kentucky",
#                 "stateId": "KY",
#                 "unit": "Million kilowatthours",
#                 "value": 74517
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "South Dakota",
#                 "stateId": "SD",
#                 "unit": "Million kilowatthours",
#                 "value": 13041
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Oregon",
#                 "stateId": "OR",
#                 "unit": "Million kilowatthours",
#                 "value": 54135
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "New Hampshire",
#                 "stateId": "NH",
#                 "unit": "Million kilowatthours",
#                 "value": 10867
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Virginia",
#                 "stateId": "VA",
#                 "unit": "Million kilowatthours",
#                 "value": 125245
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Rhode Island",
#                 "stateId": "RI",
#                 "unit": "Million kilowatthours",
#                 "value": 7398
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Minnesota",
#                 "stateId": "MN",
#                 "unit": "Million kilowatthours",
#                 "value": 66589
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "New Jersey",
#                 "stateId": "NJ",
#                 "unit": "Million kilowatthours",
#                 "value": 73070
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Pennsylvania",
#                 "stateId": "PA",
#                 "unit": "Million kilowatthours",
#                 "value": 143340
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Colorado",
#                 "stateId": "CO",
#                 "unit": "Million kilowatthours",
#                 "value": 56351
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "New Mexico",
#                 "stateId": "NM",
#                 "unit": "Million kilowatthours",
#                 "value": 25394
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Wyoming",
#                 "stateId": "WY",
#                 "unit": "Million kilowatthours",
#                 "value": 15785
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Alaska",
#                 "stateId": "AK",
#                 "unit": "Million kilowatthours",
#                 "value": 5969
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Massachusetts",
#                 "stateId": "MA",
#                 "unit": "Million kilowatthours",
#                 "value": 50798
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Iowa",
#                 "stateId": "IA",
#                 "unit": "Million kilowatthours",
#                 "value": 52893
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Nevada",
#                 "stateId": "NV",
#                 "unit": "Million kilowatthours",
#                 "value": 39032
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Texas",
#                 "stateId": "TX",
#                 "unit": "Million kilowatthours",
#                 "value": 435628
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "District of Columbia",
#                 "stateId": "DC",
#                 "unit": "Million kilowatthours",
#                 "value": 10083
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "California",
#                 "stateId": "CA",
#                 "unit": "Million kilowatthours",
#                 "value": 247250
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Vermont",
#                 "stateId": "VT",
#                 "unit": "Million kilowatthours",
#                 "value": 5413
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Utah",
#                 "stateId": "UT",
#                 "unit": "Million kilowatthours",
#                 "value": 32678
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Oklahoma",
#                 "stateId": "OK",
#                 "unit": "Million kilowatthours",
#                 "value": 64525
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Alabama",
#                 "stateId": "AL",
#                 "unit": "Million kilowatthours",
#                 "value": 85585
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Hawaii",
#                 "stateId": "HI",
#                 "unit": "Million kilowatthours",
#                 "value": 8936
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Kansas",
#                 "stateId": "KS",
#                 "unit": "Million kilowatthours",
#                 "value": 40492
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Washington",
#                 "stateId": "WA",
#                 "unit": "Million kilowatthours",
#                 "value": 88199
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Michigan",
#                 "stateId": "MI",
#                 "unit": "Million kilowatthours",
#                 "value": 99813
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Maryland",
#                 "stateId": "MD",
#                 "unit": "Million kilowatthours",
#                 "value": 59304
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "New York",
#                 "stateId": "NY",
#                 "unit": "Million kilowatthours",
#                 "value": 141424
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "West Virginia",
#                 "stateId": "WV",
#                 "unit": "Million kilowatthours",
#                 "value": 32778
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Illinois",
#                 "stateId": "IL",
#                 "unit": "Million kilowatthours",
#                 "value": 135689
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "North Dakota",
#                 "stateId": "ND",
#                 "unit": "Million kilowatthours",
#                 "value": 22863
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "South Carolina",
#                 "stateId": "SC",
#                 "unit": "Million kilowatthours",
#                 "value": 79792
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "United States",
#                 "stateId": "US",
#                 "unit": "Million kilowatthours",
#                 "value": 3805874
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "North Carolina",
#                 "stateId": "NC",
#                 "unit": "Million kilowatthours",
#                 "value": 135693
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Montana",
#                 "stateId": "MT",
#                 "unit": "Million kilowatthours",
#                 "value": 14962
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Florida",
#                 "stateId": "FL",
#                 "unit": "Million kilowatthours",
#                 "value": 241562
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Arizona",
#                 "stateId": "AZ",
#                 "unit": "Million kilowatthours",
#                 "value": 81220
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Maine",
#                 "stateId": "ME",
#                 "unit": "Million kilowatthours",
#                 "value": 11585
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Nebraska",
#                 "stateId": "NE",
#                 "unit": "Million kilowatthours",
#                 "value": 32341
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Connecticut",
#                 "stateId": "CT",
#                 "unit": "Million kilowatthours",
#                 "value": 27738
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Missouri",
#                 "stateId": "MO",
#                 "unit": "Million kilowatthours",
#                 "value": 77763
#             },
#             {
#                 "period": 2021,
#                 "seriesDescription": "Electricity total consumption (i.e., retail sales)",
#                 "seriesId": "ESTCP",
#                 "stateDescription": "Louisiana",
#                 "stateId": "LA",
#                 "unit": "Million kilowatthours",
#                 "value": 90819
#             }
#         ],
#         "dateFormat": "YYYY",
#         "description": "Estimated production, consumption, price, and expenditure data for all energy sources by state and sector.  \r\n        Source:  https://www.eia.gov/state/seds/seds-technical-notes-complete.php  \r\n        Product:  SEDS (https://www.eia.gov/state/seds/)",
#         "frequency": "annual",
#         "total": 52
#     }
# }

# %%
#Now I will take the json object (response_json) and push it into a new Pandas
#dataframe
response_dataframe = pd.DataFrame(response_json["response"]["data"])
response_dataframe.head()
# Out:
#    period seriesId                                  seriesDescription stateId  \
# 0    2021    ESTCP  Electricity total consumption (i.e., retail sa...      TN
# 1    2021    ESTCP  Electricity total consumption (i.e., retail sa...      DE
# 2    2021    ESTCP  Electricity total consumption (i.e., retail sa...      GA
# 3    2021    ESTCP  Electricity total consumption (i.e., retail sa...      IN
# 4    2021    ESTCP  Electricity total consumption (i.e., retail sa...      AR
#
#   stateDescription   value                   unit
# 0        Tennessee   99621  Million kilowatthours
# 1         Delaware   11480  Million kilowatthours
# 2          Georgia  137364  Million kilowatthours
# 3          Indiana   99740  Million kilowatthours
# 4         Arkansas   48663  Million kilowatthours

# %%
#Export dataframe to .csv
response_dataframe.to_csv('consumption_by_state_ESTCP 2021.csv')
